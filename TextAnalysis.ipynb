# %%
#nltk Program to analyse text 
import nltk 
from nltk.tokenize import sent_tokenize
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

# %%
#imporrting file and converting it into text
fPath = input("Enter File Path To Read :: ")
file = open(fPath,'r+') #TIP : Dont use binary read 
text = file.read()
file.close()
# Out:
# Enter File Path To Read :: d:\code\temp.txt

# %%
#Now Tokenize the sentences 
tkText_sent = sent_tokenize(text) #Corpus of word tokens 
tkText_word = word_tokenize(text) #corpus of sentence tokens
##################################################Lets Begin Fun###################################################

# %%
#Operation Number 1: Frequency Distribution
fDist_word = FreqDist(tkText_word)
fDist_sent = FreqDist(tkText_sent)
#print (tkText_word)

# %%
n = input ("Enter The Number Results To See :: ")
num = int(n)
print ("="*33)
print ("Top {0} most common sentencs".format(num))
print ("="*33)
print(fDist_sent.most_common(num))
print ("="*33)
print ("Top {0} most common words".format(num))
print ("="*33)
print(fDist_word.most_common(num))
# Out:
# Enter The Number Results To See :: 2
# ...
# Top 2 most common sentencs
# ...
# [('certuril.exe -hashfile \nxcopy randondkjhdhgd sjhdjhghjsd \ndir /ard/s-b \nxcopy rsjhsjsh sjhdjskjskjsh \nxcopy randossjhsjdkjhdhgd sjhdssjshjsjsd \nxcopy rssjsdhgd sjhdjhgkjshsjhhjsd\\ \nnetsh -useranme mhebookhana \npowershell.exe\nwhoami /priv \nwmic /node:computername \nwmic get os \ncopy A B \nregsvr32 /u/s/i <Temp>', 1)]
# ...
# Top 2 most common words
# ...
# [('xcopy', 4), ('wmic', 2)]

# %%
#Operation Number 2 : Frequency Distribution Plot 
fDist_word.plot(10,cumulative=False)
plt.show()

# %%
fDist_sent.plot(10,cumulative=False)
plt.figure(figsize=(20,20))
plt.show()
plt.tight_layout()
#
plt.savefig('temp.png')
